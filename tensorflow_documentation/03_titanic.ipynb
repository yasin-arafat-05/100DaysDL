# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt 
import tensorflow as tf 
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv("dataset/train.csv")
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                                 Name  \
# 316          317         1       2  Kantor, Mrs. Sinai (Miriam Sternin)
# 24            25         0       3        Palsson, Miss. Torborg Danira
# 250          251         0       3               Reed, Mr. James George
# 687          688         0       3                    Dakic, Mr. Branko
# 729          730         0       3        Ilmakangas, Miss. Pieta Sofia
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 316  female  24.0      1      0            244367  26.0000   NaN        S
# 24   female   8.0      3      1            349909  21.0750   NaN        S
# 250    male   NaN      0      0            362316   7.2500   NaN        S
# 687    male  19.0      0      0            349228  10.1708   NaN        S
# 729  female  25.0      1      0  STON/O2. 3101271   7.9250   NaN        S

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isnull().sum() / df.shape[0] * 100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
df.drop(columns=["Cabin"],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
numerical = df.select_dtypes(include=["int64","float64"])
categorical = df.select_dtypes(include=["object"])

# %%
numerical.corr()["Survived"]
# Out:
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Name: Survived, dtype: float64

# %%
delete_col = numerical.columns[numerical.corr()["Survived"]<0.1]
delete_col
# Out:
# Index(['PassengerId', 'Pclass', 'Age', 'SibSp', 'Parch'], dtype='object')

# %%
df.drop(columns=delete_col,inplace=True)

# %%
df.sample(5)
# Out:
#      Survived                            Name     Sex  Ticket     Fare  \
# 534         0             Cacic, Miss. Marija  female  315084   8.6625
# 718         0             McEvoy, Mr. Michael    male   36568  15.5000
# 652         0  Kalvik, Mr. Johannes Halvorsen    male    8475   8.4333
# 462         0               Gee, Mr. Arthur H    male  111320  38.5000
# 271         1    Tornquist, Mr. William Henry    male    LINE   0.0000
#
#     Embarked
# 534        S
# 718        Q
# 652        S
# 462        S
# 271        S

# %%
df.drop(columns=["Name","Ticket"],inplace=True)

# %%
df.sample(5)
# Out:
#      Survived     Sex      Fare Embarked
# 802         1    male  120.0000        S
# 717         1  female   10.5000        S
# 464         0    male    8.0500        S
# 158         0    male    8.6625        S
# 182         0    male   31.3875        S

# %%
df.isnull().sum()
# Out:
# Survived    0
# Sex         0
# Fare        0
# Embarked    2
# dtype: int64

# %%
X_train = df.iloc[:,1:]
y_train = df["Survived"]
X_train
# Out:
#         Sex     Fare Embarked
# 0      male   7.2500        S
# 1    female  71.2833        C
# 2    female   7.9250        S
# 3    female  53.1000        S
# 4      male   8.0500        S
# ..      ...      ...      ...
# 886    male  13.0000        S
# 887  female  30.0000        S
# 888  female  23.4500        S
# 889    male  30.0000        C
# 890    male   7.7500        Q
#
# [891 rows x 3 columns]

# %%
trans1 = ColumnTransformer(
    transformers=[
        ("impute_cat",SimpleImputer(strategy="most_frequent",add_indicator=True),[2])
    ],remainder="passthrough"
)

trans2 = ColumnTransformer(
    transformers=[
        ("ohe",OneHotEncoder(handle_unknown="ignore",sparse_output=False,drop="first"),slice(0,3))
    ],remainder="passthrough"
)

trans3 = ColumnTransformer(
    transformers=[
        ("scaling",StandardScaler(),slice(0,5))
    ],remainder="passthrough"
)

# %%
pipe = Pipeline(
    [
        ("trans1",trans1),
        ("trans2",trans2),
        ("trans3",trans3)
    ]
)
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('trans1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('impute_cat',
#                                                   SimpleImputer(add_indicator=True,
#                                                                 strategy='most_frequent'),
#                                                   [2])])),
#                 ('trans2',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   slice(0, 3, None))])),
#                 ('trans3',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('scaling', StandardScaler(),
#                                                   slice(0, 5, None))]))])

# %%
X_train = pipe.fit_transform(X_train)

# %%
X_train.shape
# Out:
# (891, 5)

# %% [markdown]
# <br>
# <br>
#
# # now make neural network layer
#
# <br>
# <br>

# %%
relu = tf.keras.activations.relu
sigmoid = tf.keras.activations.sigmoid

model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(5,activation=relu,input_dim=(5)))
model.add(tf.keras.layers.Dense(2,activation=relu))
model.add(tf.keras.layers.Dense(2,activation=relu))
model.add(tf.keras.layers.Dense(1,activation=sigmoid))

model.summary()
# Out:
# /home/yasin/allProgram/100DaysDL/code/venvML/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 5)              │            30 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 3)              │            18 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 2)              │             8 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 59 (236.00 B)
#  Trainable params: 59 (236.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
loss = tf.keras.losses.BinaryCrossentropy()
optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)

model.compile(loss=loss,optimizer=optimizer,metrics=["accuracy"])

# %%
tf.keras.

# %%
model.fit(X_train,y_train,epochs=40,validation_split=0.1)
# Out:
# Epoch 1/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.6194 - loss: 0.6756 - val_accuracy: 0.6222 - val_loss: 0.6039
# Epoch 2/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6013 - loss: 0.5993 - val_accuracy: 0.6222 - val_loss: 0.5573
# Epoch 3/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6058 - loss: 0.5692 - val_accuracy: 0.7667 - val_loss: 0.5434
# Epoch 4/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7754 - loss: 0.5484 - val_accuracy: 0.7778 - val_loss: 0.5355
# Epoch 5/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7923 - loss: 0.5214 - val_accuracy: 0.7778 - val_loss: 0.5298
# Epoch 6/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7664 - loss: 0.5474 - val_accuracy: 0.7778 - val_loss: 0.5335
# Epoch 7/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7666 - loss: 0.5241 - val_accuracy: 0.7778 - val_loss: 0.5245
# Epoch 8/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7907 - loss: 0.4985 - val_accuracy: 0.7667 - val_loss: 0.5215
# Epoch 9/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8081 - loss: 0.4854 - val_accuracy: 0.7667 - val_loss: 0.5178
# Epoch 10/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7764 - loss: 0.5183 - val_accuracy: 0.7667 - val_loss: 0.5190
# Epoch 11/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7903 - loss: 0.5045 - val_accuracy: 0.7778 - val_loss: 0.5193
# Epoch 12/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8109 - loss: 0.4708 - val_accuracy: 0.7778 - val_loss: 0.5192
# Epoch 13/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8166 - loss: 0.4835 - val_accuracy: 0.7556 - val_loss: 0.5358
# Epoch 14/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7875 - loss: 0.4906 - val_accuracy: 0.7556 - val_loss: 0.5300
# Epoch 15/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7815 - loss: 0.5128 - val_accuracy: 0.7556 - val_loss: 0.5193
# Epoch 16/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8046 - loss: 0.4859 - val_accuracy: 0.7667 - val_loss: 0.5217
# Epoch 17/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7860 - loss: 0.4967 - val_accuracy: 0.7667 - val_loss: 0.5212
# Epoch 18/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8005 - loss: 0.4832 - val_accuracy: 0.7667 - val_loss: 0.5191
# Epoch 19/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7953 - loss: 0.4894 - val_accuracy: 0.7667 - val_loss: 0.5162
# Epoch 20/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8186 - loss: 0.4602 - val_accuracy: 0.7667 - val_loss: 0.5253
# Epoch 21/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8089 - loss: 0.4766 - val_accuracy: 0.7667 - val_loss: 0.5169
# Epoch 22/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7767 - loss: 0.5218 - val_accuracy: 0.7667 - val_loss: 0.5211
# Epoch 23/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7922 - loss: 0.5004 - val_accuracy: 0.7667 - val_loss: 0.5213
# Epoch 24/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7822 - loss: 0.5015 - val_accuracy: 0.7667 - val_loss: 0.5194
# Epoch 25/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7765 - loss: 0.5049 - val_accuracy: 0.7667 - val_loss: 0.5226
# Epoch 26/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7975 - loss: 0.4773 - val_accuracy: 0.7667 - val_loss: 0.5158
# Epoch 27/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7872 - loss: 0.5018 - val_accuracy: 0.7667 - val_loss: 0.5180
# Epoch 28/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7873 - loss: 0.4908 - val_accuracy: 0.7667 - val_loss: 0.5131
# Epoch 29/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7774 - loss: 0.5025 - val_accuracy: 0.7667 - val_loss: 0.5155
# Epoch 30/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8053 - loss: 0.4807 - val_accuracy: 0.7667 - val_loss: 0.5170
# Epoch 31/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7822 - loss: 0.4994 - val_accuracy: 0.7667 - val_loss: 0.5137
# Epoch 32/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8098 - loss: 0.4784 - val_accuracy: 0.7667 - val_loss: 0.5124
# Epoch 33/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8002 - loss: 0.4858 - val_accuracy: 0.7667 - val_loss: 0.5122
# Epoch 34/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7845 - loss: 0.5052 - val_accuracy: 0.7667 - val_loss: 0.5081
# Epoch 35/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7929 - loss: 0.5030 - val_accuracy: 0.7667 - val_loss: 0.5113
# Epoch 36/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8042 - loss: 0.4790 - val_accuracy: 0.7667 - val_loss: 0.5122
# Epoch 37/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7632 - loss: 0.5316 - val_accuracy: 0.7667 - val_loss: 0.5192
# Epoch 38/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8157 - loss: 0.4766 - val_accuracy: 0.7667 - val_loss: 0.5139
# Epoch 39/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7881 - loss: 0.4956 - val_accuracy: 0.7667 - val_loss: 0.5143
# Epoch 40/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8151 - loss: 0.4832 - val_accuracy: 0.7667 - val_loss: 0.5198
